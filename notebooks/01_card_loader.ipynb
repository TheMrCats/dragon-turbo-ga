# %%
import pandas as pd

# === Step 1: Load JSON ===
file_path = "../data/ed.json"  # adjust if needed
df = pd.read_json(file_path)

# Preview the data
print("Total cards loaded:", len(df))
df.head()
# Out:
# Total cards loaded: 3681
#          id                       Name Attribute        Type  \
# 0  34541863     A Cell Breeding Device     SPELL  Continuous
# 1  64163367           A Cell Incubator     SPELL  Continuous
# 2  73262676       A Cell Scatter Burst     SPELL  Quick-Play
# 3  86988864             3-Hump Lacooda     EARTH       Beast
# 4  83994646  4-Starred Ladybug of Doom      WIND      Insect
#
#                                                 PSCT  Atk   Def        Extra  \
# 0   No Edison-Accurate PSCT available for this card.                     NaN
# 1   No Edison-Accurate PSCT available for this card.                     NaN
# 2   No Edison-Accurate PSCT available for this card.                     NaN
# 3  ① If you control 3 "3-Hump Lacooda": \nYou can...  500  1500       Effect
# 4   No Edison-Accurate PSCT available for this card.  800  1200  Flip Effect
#
#    Level damageStep Banlist
# 0    NaN        NaN     NaN
# 1    NaN        NaN     NaN
# 2    NaN        NaN     NaN
# 3    3.0        NaN     NaN
# 4    3.0          6     NaN

# %%
# Remove cards that are Forbidden
legal_df = df[~df['Banlist'].str.contains("Forbidden", na=False)]

# Limit how many of each card can be included later
# e.g., parse "Limited", "Semi-Limited", or default to "Unlimited"
def get_limit(ban_status):
    if pd.isna(ban_status):
        return 3
    elif "Limited" in ban_status and "Semi" not in ban_status:
        return 1
    elif "Semi" in ban_status:
        return 2
    return 3

legal_df = df[~df['Banlist'].str.contains("Forbidden", na=False)].copy()
legal_df["MaxCopies"] = legal_df["Banlist"].apply(get_limit)

print("Legal card count (Edison):", len(legal_df))
legal_df.sample(5)
# Out:
# Legal card count (Edison): 3638
#             id                     Name Attribute         Type  \
# 751   33875961          Dark Catapulter     EARTH      Machine
# 3160   5371656  Sword of the Soul-Eater     SPELL        Equip
# 1803  94773007               Jirai Gumo     EARTH       Insect
# 2054  84055227        Maiden of Macabre      DARK  Spellcaster
# 3392  76384284   Trojan Gladiator Beast      TRAP       Normal
#
#                                                   PSCT   Atk   Def   Extra  \
# 751   No Edison-Accurate PSCT available for this card.  1000  1500  Effect
# 3160  No Edison-Accurate PSCT available for this card.                 NaN
# 1803  No Edison-Accurate PSCT available for this card.  2200   100  Effect
# 2054  No Edison-Accurate PSCT available for this card.  1700     0  Effect
# 3392  No Edison-Accurate PSCT available for this card.                 NaN
#
#       Level damageStep Banlist  MaxCopies
# 751     4.0        NaN     NaN          3
# 3160    NaN        NaN     NaN          3
# 1803    4.0        NaN     NaN          3
# 2054    4.0          7     NaN          3
# 3392    NaN        NaN     NaN          3

# %%
# Sample whitelist of Dragon Turbo staples – add to this!
whitelist = [
    "Blue-Eyes White Dragon",
    "The White Stone of Legend",
    "Trade-In",
    "Cards of Consonance",
    "Super Rejuvenation",
    "Magical Stone Excavation",
    "Debris Dragon",
    "Vortex Trooper",
    "Upstart Goblin",
    "Pot of Avarice",
    "Card Destruction",
    "Future Fusion",
    "Instant Fusion",
    "Giant Trunade",
    "Heavy Storm",
    "Tragoedia",
    "Koa'ki Meiru Drago",
    "Reckless Greed",
    "Prime Material Dragon",
    "Flamvell Guard",
    "Dark World Dealings",
    "Allure of Darkness",
    "Foolish Burial",
    "Summoner's Art",
    "Tri-Horned Dragon",
    "Clear Vice Dragon",
    "Lightning Vortex",
    "Broww, Huntsman of Dark World",
    "Gorz the Emissary of Darkness",
]

# Filter the pool
pool_df = legal_df[legal_df["Name"].isin(whitelist)].copy()
print("Cards in whitelist pool:", len(pool_df))

# Optional: view it
pool_df[["Name", "Type", "MaxCopies"]]
# Out:
# Cards in whitelist pool: 29
#                                Name        Type  MaxCopies
# 63               Allure of Darkness      Normal          1
# 381          Blue-Eyes White Dragon      Dragon          3
# 418   Broww, Huntsman of Dark World       Fiend          3
# 458                Card Destruction      Normal          1
# 467             Cards of Consonance      Normal          3
# 538               Clear Vice Dragon      Dragon          3
# 819             Dark World Dealings      Normal          3
# 844                   Debris Dragon      Dragon          3
# 1274                 Flamvell Guard      Dragon          3
# 1294                 Foolish Burial      Normal          1
# 1347                  Future Fusion  Continuous          1
# 1419                  Giant Trunade      Normal          1
# 1499  Gorz the Emissary of Darkness       Fiend          1
# 1632                    Heavy Storm      Normal          1
# 1753                 Instant Fusion      Normal          3
# 1862             Koa'ki Meiru Drago      Dragon          3
# 1961               Lightning Vortex      Normal          3
# 2040       Magical Stone Excavation      Normal          2
# 2510                 Pot of Avarice      Normal          3
# 2535          Prime Material Dragon      Dragon          3
# 2636                 Reckless Greed      Normal          3
# 3112                 Summoner's Art      Normal          3
# 3121             Super Rejuvenation  Quick-Play          3
# 3291      The White Stone of Legend      Dragon          3
# 3354                       Trade-In      Normal          3
# 3356                      Tragoedia       Fiend          1
# 3378              Tri-Horned Dragon      Dragon          3
# 3468                 Upstart Goblin      Normal          3
# 3533                 Vortex Trooper        Aqua          3
